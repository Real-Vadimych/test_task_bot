# %%
import pandas as pd
import numpy as np

# %%
deal = pd.read_excel('reg_deals.xlsx')
deal.head()
# Out:
#   Номер мультизаявки           ИНН       Заявка Текущий статус Причина отмены  \
# 0                NaN  641802234254  Агросервисы      Завершена            NaN
# 1                NaN    9105015900  Агросервисы      Завершена            NaN
# 2                NaN    9704075070  Агросервисы      Завершена            NaN
# 3                NaN  460702516927  Агросервисы      Завершена            NaN
# 4                NaN    5252015340  Агросервисы      Завершена            NaN
#
#   Дата создания Дата окончания сделки Категория Федеральный округ  \
# 0    2021-10-04            2021-10-13       NaN               ПФО
# 1    2021-10-30            2021-10-13       NaN               ЮФО
# 2    2021-08-26            2021-10-13       NaN               ЦФО
# 3    2021-10-26            2021-10-27       NaN               ЦФО
# 4    2021-11-16            2021-11-21       NaN               ПФО
#
#   Область / Край /Республика Оплата прошла Item Type
# ...

# %%
deal.describe(include='all')
# Out:
# C:\Users\KVV_1\AppData\Local\Temp\ipykernel_35636\1234915847.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   deal.describe(include='all')
# C:\Users\KVV_1\AppData\Local\Temp\ipykernel_35636\1234915847.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   deal.describe(include='all')
#        Номер мультизаявки           ИНН          Заявка      Текущий статус  \
# count                 565          3313            3313                3313
# unique                116          2021               6                  19
# ...

# %%
deal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Номер мультизаявки          565 non-null    object
#  1   ИНН                         3313 non-null   object
#  2   Заявка                      3313 non-null   object
#  3   Текущий статус              3313 non-null   object
#  4   Причина отмены              2983 non-null   object
#  5   Дата создания               3313 non-null   datetime64[ns]
#  6   Дата окончания сделки       3106 non-null   datetime64[ns]
#  7   Категория                   1129 non-null   object
#  8   Федеральный округ           3313 non-null   object
#  9   Область / Край /Республика  3313 non-null   object
#  10  Оплата прошла               1074 non-null   object
#  11  Item Type                   3313 non-null   object
# dtypes: datetime64[ns](2), object(10)
# ...

# %%
deal['Заявка'].value_counts()
# Out:
# Финансирование                  2248
# Продажа урожая                   737
# Сельхозтовары                    235
# Агросервисы                       89
# Агросервисы​                       3
# Агросервисы                        1
# Name: Заявка, dtype: int64

# %%
deal['Текущий статус'].value_counts()
# Out:
# Отменена партнером                        1282
# Отменена фермером                          974
# Мультизаявка_отменена партнером            249
# Отменена Админом                           196
# Мультизаявка_отменена админом              168
# Завершена                                  113
# SENT                                        94
# Активная                                    64
# Мультизаявка_отменена автоматически         45
# Мультизаявка_отменена фермером              44
# Мультизаявка                                38
# Отменена КЦ                                 24
# Мультизаявка_активная                        8
# LJqrb?PV5KD3"*c#                             7
# Завершена​                                   2
# Проверена КЦ на минимальные требования       2
# Отменена Админом​                            1
# Холд                                         1
# Завершена 1я отгрузка                        1
# Name: Текущий статус, dtype: int64

# %%
deal[deal['Текущий статус'] == 'LJqrb?PV5KD3"*c#']
# Out:
#      Номер мультизаявки           ИНН                        Заявка  \
# 8                   NaN    2258004934  Агросервисы
# 24                  NaN    2247004890                  Агросервисы​
# 37                  NaN    2221226560                  Агросервисы​
# 39                  NaN  228001115705                  Агросервисы​
# 45                  NaN    2287006573                   Агросервисы
# 65                  NaN  228601261553                   Агросервисы
# 1326                NaN  225802946618                Финансирование
#
#         Текущий статус Причина отмены Дата создания Дата окончания сделки  \
# 8     LJqrb?PV5KD3"*c#            NaN    2021-11-29            2021-11-28
# 24    LJqrb?PV5KD3"*c#            NaN    2021-12-28            2022-01-21
# 37    LJqrb?PV5KD3"*c#            NaN    2022-02-08            2022-02-15
# 39    LJqrb?PV5KD3"*c#            NaN    2022-02-14            2022-02-15
# ...

# %%
deal['Текущий статус'] = deal['Текущий статус'].replace(['LJqrb?PV5KD3"*c#'], 'другое')

# %%
deal['Текущий статус'].value_counts()
# Out:
# Отменена партнером                        1282
# Отменена фермером                          974
# Мультизаявка_отменена партнером            249
# Отменена Админом                           196
# Мультизаявка_отменена админом              168
# Завершена                                  113
# SENT                                        94
# Активная                                    64
# Мультизаявка_отменена автоматически         45
# Мультизаявка_отменена фермером              44
# Мультизаявка                                38
# Отменена КЦ                                 24
# Мультизаявка_активная                        8
# другое                                       7
# Завершена​                                   2
# Проверена КЦ на минимальные требования       2
# Отменена Админом​                            1
# Холд                                         1
# Завершена 1я отгрузка                        1
# Name: Текущий статус, dtype: int64

# %%
deal['ИНН'].describe()
# Out:
# count             3313
# unique            2021
# top       262505015969
# freq                40
# Name: ИНН, dtype: object

# %%
deal['ИНН'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# c:\Users\KVV_1\YandexDisk\Documents\тесты\поле РФ\seek-n-destroy.ipynb Cell 11 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KVV_1/YandexDisk/Documents/%D1%82%D0%B5%D1%81%D1%82%D1%8B/%D0%BF%D0%BE%D0%BB%D0%B5%20%D0%A0%D0%A4/seek-n-destroy.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> deal['ИНН'].astype(int)
#
# File c:\Users\KVV_1\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:5920, in NDFrame.astype(self, dtype, copy, errors)
#    5913     results = [
#    5914         self.iloc[:, i].astype(dtype, copy=copy)
#    5915         for i in range(len(self.columns))
#    5916     ]
#    5918 else:
#    5919     # else, only a single dtype is given
# -> 5920     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
def check_int(value):
	try:
		int(value)
		return np.NaN
	except ValueError:
		return value

# %%
deal.ИНН.apply(check_int).dropna()
# Out:
# 163       1650310080<br>
# 167       5824002830<br>
# 172       6727037491<br>
# 173       6727037491<br>
# 197       7703704469<br>
# 198       7703704469<br>
# 1902    234800631582<br>
# 1904      5824002830<br>
# 1919    742801019315<br>
# 2331      5248012924<br>
# 2332      4618003185<br>
# 2333      4618003185<br>
# 2915      5260467830<br>
# Name: ИНН, dtype: object

# %%
deal.ИНН = deal.ИНН.str.replace(r'\D+', '', regex=True)

# %%
deal.ИНН.apply(check_int).dropna()
# Out:
# Series([], Name: ИНН, dtype: float64)

# %%
deal['Причина отмены'].describe()
# Out:
# count                                     2983
# unique                                      46
# top       Фермер не обозначил реальную причину
# freq                                       645
# Name: Причина отмены, dtype: object

# %%
deal['Причина отмены'].value_counts()
# Out:
# Фермер не обозначил реальную причину                     645
# Окончательный недозвон                                   394
# Отказ партнера                                           328
# Не произошло конвертации в лид                           210
# Пробная/измененная заявка                                190
# Не устроило ценовое предложение                          177
# Неактуально для фермера                                  175
# Не пройдена проверка                                     160
# Закупщик не закупает культуру                            120
# Временно не закупают в регионе                            83
# Нет нужного сервиса / услуги                              69
# Нарушение SLA со стороны партнера                         52
# Автоотмена                                                44
# Товара на текущий момент нет в наличии у поставщика       43
# Нарушение SLA со стороны фермера                          40
# ...

# %%
deal['Причина отмены'].isna().count()
# Out:
# 3313

# %%
deal['Категория'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3313 entries, 0 to 3312
# Series name: Категория
# Non-Null Count  Dtype
# --------------  -----
# 1129 non-null   object
# dtypes: object(1)
# memory usage: 26.0+ KB

# %%
deal['Категория'].value_counts()
# Out:
# Пшеница                                                                                                                                                                                                                                                                                                                                                                388
# Подсолнечник масличный                                                                                                                                                                                                                                                                                                                                                 130
# ...

# %%
deal[deal['Категория'] == '`54WVhT"J3wxhdkm']
# Out:
#      Номер мультизаявки           ИНН          Заявка Текущий статус  \
# 1901                NaN  461800197340  Финансирование       Активная
# 1904                NaN    5824002830  Финансирование       Активная
# 1912                NaN  081406926204  Финансирование       Активная
# 1913                NaN  023201556318  Финансирование       Активная
# 1919                NaN  742801019315  Финансирование       Активная
# 1928                NaN  060102798108  Финансирование       Активная
# 1930                NaN  261902112406  Финансирование       Активная
# 1935                NaN  245011369199  Финансирование       Активная
# 1938                NaN   90107441894  Финансирование       Активная
# 1940                NaN  570300863454  Финансирование       Активная
# 1946                NaN  235404863510  Финансирование       Активная
# 1948                NaN    6140031289  Финансирование       Активная
# 1949                NaN  371600160963  Финансирование       Активная
# ...

# %%
deal['Категория'] = deal['Категория'].replace(['`54WVhT"J3wxhdkm'], 'другое')

# %%
deal[deal['Категория'] == 'data.capital\tУставной капитал компании\n└ type\t— тип капитала\n└ value\t— размер капитала\ndata.finance\tФинансовые показатели за год\nчастично заполнены у 70% действующих компаний\n└ year\t— год бух. отчетности\n└ income\t— доходы по бух. отчетности\n└ expense\t— расходы по бух. отчетности\n└ debt\t— недоимки по налогам\n└ penalty\t— налоговые штрафы']
# Out:
#      Номер мультизаявки         ИНН          Заявка Текущий статус  \
# 1687                NaN  1651079725  Финансирование           SENT
#
#      Причина отмены Дата создания Дата окончания сделки  \
# 1687            NaN    2021-11-01                   NaT
#
#                                               Категория Федеральный округ  \
# 1687  data.capital\tУставной капитал компании\n└ typ...               ПФО
#
#             Область / Край /Республика Оплата прошла Item Type
# 1687  Республика Татарстан (Татарстан)           NaN   Элемент

# %%
deal[deal['ИНН'] == '1651079725']
# Out:
#      Номер мультизаявки         ИНН          Заявка Текущий статус  \
# 1687                NaN  1651079725  Финансирование           SENT
#
#      Причина отмены Дата создания Дата окончания сделки  \
# 1687            NaN    2021-11-01                   NaT
#
#                                               Категория Федеральный округ  \
# 1687  data.capital\tУставной капитал компании\n└ typ...               ПФО
#
#             Область / Край /Республика Оплата прошла Item Type
# 1687  Республика Татарстан (Татарстан)           NaN   Элемент

# %%
deal = deal.drop(deal[deal['ИНН'] == '1651079725'].index)

# %%
deal[deal['ИНН'] == '1651079725']
# Out:
# Empty DataFrame
# Columns: [Номер мультизаявки, ИНН, Заявка, Текущий статус, Причина отмены, Дата создания, Дата окончания сделки, Категория, Федеральный округ, Область / Край /Республика, Оплата прошла, Item Type]
# Index: []

# %%
deal['Федеральный округ'].value_counts()
# Out:
# ЦФО     902
# ЮФО     642
# СКФО    512
# ПФО     456
# СФО     295
# ДФО     194
# УФО     176
# СЗФО    135
# Name: Федеральный округ, dtype: int64

# %%
deal['Область / Край /Республика'].value_counts()
# Out:
# Краснодарский край                                     304
# Воронежская область                                    241
# Ставропольский край                                    240
# г. Москва                                              189
# Волгоградская область                                  140
#                                                       ...
# Саха (Якутия)                                            2
# Удмуртская республика                                    2
# Чувашская республика - Чувашия                           2
# Севастополь                                              1
# Иные территории, включая город и космодром Байконур      1
# Name: Область / Край /Республика, Length: 90, dtype: int64

# %%
deal['Оплата прошла'].value_counts()
# Out:
# Нет    962
# Да     112
# Name: Оплата прошла, dtype: int64

# %%
deal['Item Type'].value_counts()
# Out:
# Элемент    3312
# Name: Item Type, dtype: int64

# %%
deal.shape
# Out:
# (3312, 12)

# %%
# Поскольку у меня не получилось руками поменять тип поля в DataLens с числа на строку, чтобы связать с inn в таблице _organizations (я ее не чистил, и там есть строковые значения),
# пришлось добавить эту строку, чтобы обмануть Datalens

deal = deal.append({'ИНН': 'empty string'}, ignore_index=True)
# Out:
# C:\Users\KVV_1\AppData\Local\Temp\ipykernel_35636\3663018632.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   deal = deal.append({'ИНН': 'empty string'}, ignore_index=True)

# %%
deal.shape
# Out:
# (3313, 12)

# %%
deal.to_csv('reg_deals.csv', index=False)
